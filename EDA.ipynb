# %% [markdown]
# <a href="https://colab.research.google.com/github/maetthil/NASASpaceApps/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import glob

# %%
def load_parquet(pattern):
    dfs = []
    for f in glob.glob(pattern):
        dfs.append(pd.read_parquet(f))
    return pd.concat(dfs)

# %%
wind_df = load_parquet('wind_*.parquet')
dscovr_df = load_parquet('dscovr_*.parquet')

# %%
wind_df.head(10)
# Out:
#      Bx_GSM    Gy_GSM    Bz_GSM         epoch
# 0 -1.331802  3.362687  0.938039  6.368216e+13
# 1 -1.360493  3.374089  0.971866  6.368216e+13
# 2 -1.328466  3.362759  0.972152  6.368216e+13
# 3 -1.337833  3.343617  0.988543  6.368216e+13
# 4 -1.341525  3.374133  0.995609  6.368216e+13
# 5 -1.368890  3.401918  0.963196  6.368216e+13
# 6 -1.367381  3.394371  0.974967  6.368216e+13
# 7 -1.337001  3.348177  0.965651  6.368216e+13
# 8 -1.367197  3.334416  0.990294  6.368216e+13
# 9 -1.346670  3.359260  0.987815  6.368216e+13

# %%
dscovr_df.head(10)
# Out:
#      Bx_GSM    Gy_GSM    Bz_GSM         epoch
# 0  5.837182  2.314090 -7.158201  6.368198e+13
# 1  5.899103  2.184921 -7.075517  6.368198e+13
# 2  6.042387  2.221216 -7.145005  6.368198e+13
# 3  5.720763  2.225209 -6.768812  6.368198e+13
# 4  5.578448  2.175153 -6.790361  6.368198e+13
# 5  5.604666  2.219544 -6.776843  6.368198e+13
# 6  5.942960  2.215452 -6.977218  6.368198e+13
# 7  5.817309  2.211638 -6.760045  6.368198e+13
# 8  5.747712  2.103139 -6.801715  6.368198e+13
# 9  5.726715  2.153614 -6.865539  6.368198e+13

# %%
wind_df.drop(['epoch'], axis=1).plot()
